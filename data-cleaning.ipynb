# %% [markdown]
# # **Cleaning Credit Card Complaint Dataset**

# %% [markdown]
# Importing necessary libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the datset

# %%
df = pd.read_csv("credit_card_complaints.csv")

# %% [markdown]
# Analysing dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 87718 entries, 0 to 87717
#
# Data columns (total 18 columns):
#
#  #   Column                        Non-Null Count  Dtype
#
# ---  ------                        --------------  -----
#
#  0   date_received                 87718 non-null  object
#
#  1   product                       87718 non-null  object
#
#  2   sub_product                   0 non-null      float64
#
#  3   issue                         87718 non-null  object
#
#  4   sub_issue                     0 non-null      float64
#
#  5   consumer_complaint_narrative  17433 non-null  object
#
#  6   company_public_response       19956 non-null  object
#
#  7   company                       87718 non-null  object
#
#  8   state                         86980 non-null  object
#
#  9   zip_code                      86980 non-null  object
#
#  10  tags                          13258 non-null  object
#
#  11  consumer_consent_provided     29563 non-null  object
#
#  12  submitted_via                 87717 non-null  object
#
#  13  date_sent_to_company          87718 non-null  object
#
#  14  company_response_to_consumer  87718 non-null  object
#
#  15  timely_response               87718 non-null  bool
#
#  16  consumer_disputed             83908 non-null  object
#
#  17  complaint_id                  87718 non-null  int64
#
# dtypes: bool(1), float64(2), int64(1), object(14)
#
# memory usage: 11.5+ MB

# %%
df.columns
# Out:
# Index(['date_received', 'product', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zip_code', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed', 'complaint_id'],
#       dtype='object')

# %%
initial_cols,initial_rows = df.shape[1], df.shape[0]
print("Columns: ", initial_cols)
print(f"Rows: {initial_rows:,}")
# Out:
# Columns:  18
#
# Rows: 87,718

# %%
initial_total_values = initial_rows * initial_cols
print(f"Total values: {initial_total_values:,}")
# Out:
# Total values: 1,578,924

# %%
df.head()
# Out:
#   date_received      product  sub_product                          issue  \
# 0    2013-07-29  Credit card          NaN              Billing statement
# 1    2013-07-29  Credit card          NaN           APR or interest rate
# 2    2013-07-29  Credit card          NaN             Delinquent account
# 3    2013-07-29  Credit card          NaN               Billing disputes
# 4    2013-07-29  Credit card          NaN  Credit line increase/decrease
#
#    sub_issue consumer_complaint_narrative company_public_response  \
# 0        NaN                          NaN                     NaN
# 1        NaN                          NaN                     NaN
# 2        NaN                          NaN                     NaN
# 3        NaN                          NaN                     NaN
# 4        NaN                          NaN                     NaN
#
#                company state zip_code            tags  \
# 0             Citibank    OH    45247             NaN
# 1  Synchrony Financial    WA    98548             NaN
# 2                 Amex    TX    78232             NaN
# 3          Capital One    FL    32226   Servicemember
# 4             Citibank    WI    53066  Older American
#
#   consumer_consent_provided submitted_via date_sent_to_company  \
# 0                       NaN      Referral           2013-07-30
# 1                       NaN           Web           2013-07-29
# 2                       NaN           Web           2013-07-29
# 3                       NaN           Web           2013-07-29
# 4                       NaN         Phone           2013-07-30
#
#   company_response_to_consumer  timely_response consumer_disputed  \
# 0      Closed with explanation             True              True
# 1  Closed with monetary relief             True             False
# 2  Closed with monetary relief             True             False
# 3      Closed with explanation             True             False
# 4      Closed with explanation             True              True
#
#    complaint_id
# 0        469026
# 1        469131
# 2        479990
# 3        475777
# 4        469473

# %%
duplicates = df.duplicated()
d_count = duplicates.sum()

print(f"Number of duplicates: {d_count}")
# Out:
# Number of duplicates: 0

# %%
other_products = df[df['product'] != 'Credit card']
other_products.head()
o_count = len(other_products)
print("Count of products other than credit card: ",o_count)
# Out:
# Count of products other than credit card:  0

# %%
df = df.drop(['product'], axis=1)
df.head()
# Out:
#   date_received  sub_product                          issue  sub_issue  \
# 0    2013-07-29          NaN              Billing statement        NaN
# 1    2013-07-29          NaN           APR or interest rate        NaN
# 2    2013-07-29          NaN             Delinquent account        NaN
# 3    2013-07-29          NaN               Billing disputes        NaN
# 4    2013-07-29          NaN  Credit line increase/decrease        NaN
#
#   consumer_complaint_narrative company_public_response              company  \
# 0                          NaN                     NaN             Citibank
# 1                          NaN                     NaN  Synchrony Financial
# 2                          NaN                     NaN                 Amex
# 3                          NaN                     NaN          Capital One
# 4                          NaN                     NaN             Citibank
#
#   state zip_code            tags consumer_consent_provided submitted_via  \
# 0    OH    45247             NaN                       NaN      Referral
# 1    WA    98548             NaN                       NaN           Web
# 2    TX    78232             NaN                       NaN           Web
# 3    FL    32226   Servicemember                       NaN           Web
# 4    WI    53066  Older American                       NaN         Phone
#
#   date_sent_to_company company_response_to_consumer  timely_response  \
# 0           2013-07-30      Closed with explanation             True
# 1           2013-07-29  Closed with monetary relief             True
# 2           2013-07-29  Closed with monetary relief             True
# 3           2013-07-29      Closed with explanation             True
# 4           2013-07-30      Closed with explanation             True
#
#   consumer_disputed  complaint_id
# 0              True        469026
# 1             False        469131
# 2             False        479990
# 3             False        475777
# 4              True        469473

# %%
initial_null_values = df.isnull().sum().sum()
print(f"Total NaN values: {initial_null_values:,}")
# Out:
# Total NaN values: 451,385

# %%
si_null = df['sub_issue'].isnull().sum()
cpr_null = df['company_public_response'].isnull().sum()
ccn_null = df['consumer_complaint_narrative'].isnull().sum()
ccp_null = df['consumer_consent_provided'].isnull().sum()

print(f"Null value % in sub_issue: {si_null/len(df)*100:.2f}%")
print(f"Null value % in consumer_complaint_narrative: {ccn_null/len(df)*100:.2f}%")
print(f"Null value % in company_public_response: {cpr_null/len(df)*100:.2f}%")
print(f"Null value % in consumer_consent_provided: {ccp_null/len(df)*100:.2f}%")
# Out:
# Null value % in sub_issue: 100.00%
#
# Null value % in consumer_complaint_narrative: 80.13%
#
# Null value % in company_public_response: 77.25%
#
# Null value % in consumer_consent_provided: 66.30%

# %%
df = df.drop(['sub_issue','consumer_complaint_narrative','company_public_response'], axis=1)
df.head()
# Out:
#   date_received  sub_product                          issue  \
# 0    2013-07-29          NaN              Billing statement
# 1    2013-07-29          NaN           APR or interest rate
# 2    2013-07-29          NaN             Delinquent account
# 3    2013-07-29          NaN               Billing disputes
# 4    2013-07-29          NaN  Credit line increase/decrease
#
#                company state zip_code            tags  \
# 0             Citibank    OH    45247             NaN
# 1  Synchrony Financial    WA    98548             NaN
# 2                 Amex    TX    78232             NaN
# 3          Capital One    FL    32226   Servicemember
# 4             Citibank    WI    53066  Older American
#
#   consumer_consent_provided submitted_via date_sent_to_company  \
# 0                       NaN      Referral           2013-07-30
# 1                       NaN           Web           2013-07-29
# 2                       NaN           Web           2013-07-29
# 3                       NaN           Web           2013-07-29
# 4                       NaN         Phone           2013-07-30
#
#   company_response_to_consumer  timely_response consumer_disputed  \
# 0      Closed with explanation             True              True
# 1  Closed with monetary relief             True             False
# 2  Closed with monetary relief             True             False
# 3      Closed with explanation             True             False
# 4      Closed with explanation             True              True
#
#    complaint_id
# 0        469026
# 1        469131
# 2        479990
# 3        475777
# 4        469473

# %%
df.dropna(subset=['consumer_consent_provided'], inplace=True)

# %%
null_values = df.isnull().sum().sum()
print(f"Initial NaN values: {initial_null_values:,}")
print(f"Current NaN values: {null_values:,}")
# Out:
# Initial NaN values: 451,385
#
# Current NaN values: 56,524

# %%
df.head()
# Out:
#      date_received  sub_product                 issue  \
# 1611    2016-12-15          NaN  Credit determination
# 5653    2015-03-24          NaN                 Other
# 5671    2015-03-23          NaN               Rewards
# 5673    2015-03-23          NaN                 Other
# 5675    2015-03-23          NaN                 Other
#
#                              company state zip_code tags  \
# 1611                    U.S. Bancorp    NV    89117  NaN
# 5653                     Capital One    OH    440XX  NaN
# 5671  Citizens Financial Group, Inc.    MI    482XX  NaN
# 5673                        Citibank    CA    91367  NaN
# 5675                        Discover    MD    217XX  NaN
#
#      consumer_consent_provided submitted_via date_sent_to_company  \
# 1611      Consent not provided           Web           2016-12-15
# 5653          Consent provided           Web           2015-03-30
# 5671          Consent provided           Web           2015-03-23
# 5673      Consent not provided           Web           2015-03-23
# 5675          Consent provided           Web           2015-03-23
#
#          company_response_to_consumer  timely_response consumer_disputed  \
# 1611          Closed with explanation             True             False
# 5653          Closed with explanation             True             False
# 5671          Closed with explanation             True              True
# 5673      Closed with monetary relief             True             False
# 5675  Closed with non-monetary relief             True             False
#
#       complaint_id
# 1611       2251919
# 5653       1297939
# 5671       1296693
# 5673       1296638
# 5675       1295056

# %%
sp_null = df['sub_product'].isnull().sum()
tags_null = df['tags'].isnull().sum()

print(f"Null value % in sub_issue: {sp_null/len(df)*100:.2f}%")
print(f"Null value % in consumer_complaint_narrative: {tags_null/len(df)*100:.2f}%")
# Out:
# Null value % in sub_issue: 100.00%
#
# Null value % in consumer_complaint_narrative: 85.25%

# %%
df = df.drop(['sub_product', 'tags'], axis=1)
df.head()
# Out:
#      date_received                 issue                         company  \
# 1611    2016-12-15  Credit determination                    U.S. Bancorp
# 5653    2015-03-24                 Other                     Capital One
# 5671    2015-03-23               Rewards  Citizens Financial Group, Inc.
# 5673    2015-03-23                 Other                        Citibank
# 5675    2015-03-23                 Other                        Discover
#
#      state zip_code consumer_consent_provided submitted_via  \
# 1611    NV    89117      Consent not provided           Web
# 5653    OH    440XX          Consent provided           Web
# 5671    MI    482XX          Consent provided           Web
# 5673    CA    91367      Consent not provided           Web
# 5675    MD    217XX          Consent provided           Web
#
#      date_sent_to_company     company_response_to_consumer  timely_response  \
# 1611           2016-12-15          Closed with explanation             True
# 5653           2015-03-30          Closed with explanation             True
# 5671           2015-03-23          Closed with explanation             True
# 5673           2015-03-23      Closed with monetary relief             True
# 5675           2015-03-23  Closed with non-monetary relief             True
#
#      consumer_disputed  complaint_id
# 1611             False       2251919
# 5653             False       1297939
# 5671              True       1296693
# 5673             False       1296638
# 5675             False       1295056

# %%
null_values = df.isnull().sum().sum()
print(f"Initial NaN values: {initial_null_values:,}")
print(f"Current NaN values: {null_values:,}")
# Out:
# Initial NaN values: 451,385
#
# Current NaN values: 1,760

# %%
print( df['zip_code'].dtype )
print( df['date_sent_to_company'].dtype )
# Out:
# object
#
# object

# %%
df = df.drop(['zip_code'], axis=1)

# %%
df = df.drop(['complaint_id'], axis=1)

# %%
cols,rows = df.shape[1], df.shape[0]
null_values = df.isnull().sum().sum()

print(f"Total Values: {cols*rows:,}")
print(f"Total NaN values: {null_values:,}")
print(f"% of NaN values: {null_values/(cols*rows)*100:.2f}")
# Out:
# Total Values: 295,630
#
# Total NaN values: 1,666
#
# % of NaN values: 0.56

# %%
# converting to datetime objects
df['date_received'] = pd.to_datetime(df['date_received'])
df['date_sent_to_company'] = pd.to_datetime(df['date_sent_to_company'])

print(df['date_received'].dtype)
print(df['date_sent_to_company'].dtype)
# Out:
# datetime64[ns]
#
# datetime64[ns]

# %%
df['time_difference'] = (df['date_sent_to_company'] - df['date_received']).dt.days
df = df.drop(['date_sent_to_company','date_received'],axis=1)

# %%
df.head()
# Out:
#                      issue                         company state  \
# 1611  Credit determination                    U.S. Bancorp    NV
# 5653                 Other                     Capital One    OH
# 5671               Rewards  Citizens Financial Group, Inc.    MI
# 5673                 Other                        Citibank    CA
# 5675                 Other                        Discover    MD
#
#      consumer_consent_provided submitted_via     company_response_to_consumer  \
# 1611      Consent not provided           Web          Closed with explanation
# 5653          Consent provided           Web          Closed with explanation
# 5671          Consent provided           Web          Closed with explanation
# 5673      Consent not provided           Web      Closed with monetary relief
# 5675          Consent provided           Web  Closed with non-monetary relief
#
#       timely_response consumer_disputed  time_difference
# 1611             True             False                0
# 5653             True             False                6
# 5671             True              True                0
# 5673             True             False                0
# 5675             True             False                0

# %%
# removing incorrect responses
df = df[df['time_difference'] >= 0]
df.head()
# Out:
#                      issue                         company state  \
# 1611  Credit determination                    U.S. Bancorp    NV
# 5653                 Other                     Capital One    OH
# 5671               Rewards  Citizens Financial Group, Inc.    MI
# 5673                 Other                        Citibank    CA
# 5675                 Other                        Discover    MD
#
#      consumer_consent_provided submitted_via     company_response_to_consumer  \
# 1611      Consent not provided           Web          Closed with explanation
# 5653          Consent provided           Web          Closed with explanation
# 5671          Consent provided           Web          Closed with explanation
# 5673      Consent not provided           Web      Closed with monetary relief
# 5675          Consent provided           Web  Closed with non-monetary relief
#
#       timely_response consumer_disputed  time_difference
# 1611             True             False                0
# 5653             True             False                6
# 5671             True              True                0
# 5673             True             False                0
# 5675             True             False                0

# %%
df.columns
# Out:
# Index(['issue', 'company', 'state', 'consumer_consent_provided',
#        'submitted_via', 'company_response_to_consumer', 'timely_response',
#        'consumer_disputed', 'time_difference'],
#       dtype='object')

# %% [markdown]
# Categorical Data Encoding and Labeling

# %%
df_encoded = pd.get_dummies(df, columns=['company_response_to_consumer','submitted_via','company','issue','state'])

label_encoder = LabelEncoder()
df_encoded['consumer_disputed'] = label_encoder.fit_transform(df_encoded['consumer_disputed'])
df_encoded['timely_response'] = label_encoder.fit_transform(df_encoded['timely_response'])

df_encoded.head()
# Out:
#      consumer_consent_provided  timely_response  consumer_disputed  \
# 1611      Consent not provided                1                  0
# 5653          Consent provided                1                  0
# 5671          Consent provided                1                  1
# 5673      Consent not provided                1                  0
# 5675          Consent provided                1                  0
#
#       time_difference  company_response_to_consumer_Closed  \
# 1611                0                                    0
# 5653                6                                    0
# 5671                0                                    0
# 5673                0                                    0
# 5675                0                                    0
#
#       company_response_to_consumer_Closed with explanation  \
# 1611                                                  1
# 5653                                                  1
# 5671                                                  1
# 5673                                                  0
# 5675                                                  0
#
#       company_response_to_consumer_Closed with monetary relief  \
# 1611                                                  0
# 5653                                                  0
# 5671                                                  0
# 5673                                                  1
# 5675                                                  0
#
#       company_response_to_consumer_Closed with non-monetary relief  \
# 1611                                                  0
# 5653                                                  0
# 5671                                                  0
# 5673                                                  0
# 5675                                                  1
#
#       company_response_to_consumer_In progress  \
# 1611                                         0
# 5653                                         0
# 5671                                         0
# 5673                                         0
# 5675                                         0
#
#       company_response_to_consumer_Untimely response  ...  state_TN  state_TX  \
# 1611                                               0  ...         0         0
# 5653                                               0  ...         0         0
# 5671                                               0  ...         0         0
# 5673                                               0  ...         0         0
# 5675                                               0  ...         0         0
#
#       state_UT  state_VA  state_VI  state_VT  state_WA  state_WI  state_WV  \
# 1611         0         0         0         0         0         0         0
# 5653         0         0         0         0         0         0         0
# 5671         0         0         0         0         0         0         0
# 5673         0         0         0         0         0         0         0
# 5675         0         0         0         0         0         0         0
#
#       state_WY
# 1611         0
# 5653         0
# 5671         0
# 5673         0
# 5675         0
#
# [5 rows x 386 columns]

# %%
df_encoded['consumer_consent_provided'] = df_encoded['consumer_consent_provided'].apply(lambda x: 1 if x == 'Consent provided' else 0)
df_encoded.head()
# Out:
#       consumer_consent_provided  timely_response  consumer_disputed  \
# 1611                          0                1                  0
# 5653                          0                1                  0
# 5671                          0                1                  1
# 5673                          0                1                  0
# 5675                          0                1                  0
#
#       time_difference  company_response_to_consumer_Closed  \
# 1611                0                                    0
# 5653                6                                    0
# 5671                0                                    0
# 5673                0                                    0
# 5675                0                                    0
#
#       company_response_to_consumer_Closed with explanation  \
# 1611                                                  1
# 5653                                                  1
# 5671                                                  1
# 5673                                                  0
# 5675                                                  0
#
#       company_response_to_consumer_Closed with monetary relief  \
# 1611                                                  0
# 5653                                                  0
# 5671                                                  0
# 5673                                                  1
# 5675                                                  0
#
#       company_response_to_consumer_Closed with non-monetary relief  \
# 1611                                                  0
# 5653                                                  0
# 5671                                                  0
# 5673                                                  0
# 5675                                                  1
#
#       company_response_to_consumer_In progress  \
# 1611                                         0
# 5653                                         0
# 5671                                         0
# 5673                                         0
# 5675                                         0
#
#       company_response_to_consumer_Untimely response  ...  state_TN  state_TX  \
# 1611                                               0  ...         0         0
# 5653                                               0  ...         0         0
# 5671                                               0  ...         0         0
# 5673                                               0  ...         0         0
# 5675                                               0  ...         0         0
#
#       state_UT  state_VA  state_VI  state_VT  state_WA  state_WI  state_WV  \
# 1611         0         0         0         0         0         0         0
# 5653         0         0         0         0         0         0         0
# 5671         0         0         0         0         0         0         0
# 5673         0         0         0         0         0         0         0
# 5675         0         0         0         0         0         0         0
#
#       state_WY
# 1611         0
# 5653         0
# 5671         0
# 5673         0
# 5675         0
#
# [5 rows x 386 columns]

# %%
df.to_csv('Downloads\\cleaned_data.csv', index=False)
